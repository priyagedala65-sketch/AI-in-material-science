# %%
## Session 16*

# %%
import pandas as pd
import numpy as np

# 1. Sample dataset containing chemical formulas
df = pd.DataFrame({'Formula': ['Fe2O3', 'Al2O3', 'TiO2', 'SiO2']})

# 2. Conceptual dictionary lookup for an elemental property (e.g., Electronegativity)
# In professional workflows, automated libraries handle periodic table mappings.
electronegativity_map = {'Fe': 1.83, 'Al': 1.61, 'Ti': 1.54, 'Si': 1.90, 'O': 3.44}

print("✅ Dataset initialized. Ready for elemental property statistical aggregation.")
# Out:
# ✅ Dataset initialized. Ready for elemental property statistical aggregation.
